# %% [markdown]
# <a href="https://colab.research.google.com/github/nsankaran-usf/NEURO201/blob/main/Colab2PDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install texlive texlive-xetex texlive-latex-extra pandoc
# !pip install pypandoc
# !pip install pandoc
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   dvisvgm fonts-droid-fallback fonts-lato fonts-lmodern fonts-noto-mono
#   fonts-texgyre fonts-urw-base35 libapache-pom-java
#   libcmark-gfm-extensions0.29.0.gfm.3 libcmark-gfm0.29.0.gfm.3
#   libcommons-logging-java libcommons-parent-java libfontbox-java libgs9
#   libgs9-common libidn12 libijs-0.35 libjbig2dec0 libkpathsea6 libpdfbox-java
#   libptexenc1 libruby3.0 libsynctex2 libteckit0 libtexlua53 libtexluajit2
#   libwoff1 libzzip-0-13 lmodern pandoc-data poppler-data preview-latex-style
#   rake ruby ruby-net-telnet ruby-rubygems ruby-webrick ruby-xmlrpc ruby3.0
#   rubygems-integration t1utils teckit tex-common tex-gyre texlive-base
#   texlive-binaries texlive-fonts-recommended texlive-latex-base
#   texlive-latex-recommended texlive-pictures texlive-plain-generic tipa
#   xfonts-encodings xfonts-utils
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %ls
# Out:
# drive/  sample_data/

# %%
# %cd drive/MyDrive/Colab\ Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !jupyter nbconvert --to PDF "Copy of Introduction to Jupyter Notebook.ipynb"
# Out:
# [NbConvertApp] Converting notebook Copy of Introduction to Jupyter Notebook.ipynb to PDF
# [NbConvertApp] Writing 39530 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 62059 bytes to Copy of Introduction to Jupyter Notebook.pdf

# %%
# this is just to show a pdf version of this notebook as well please disregard
# !jupyter nbconvert --to PDF "Colab2PDF.ipynb"
# Out:
# [NbConvertApp] Converting notebook Colab2PDF.ipynb to PDF
# [NbConvertApp] Writing 61448 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 43987 bytes to Colab2PDF.pdf

# %%
drive.flush_and_unmount()
