# %% [markdown]
# ## **Statistical analysis in python: The normal distribution, probabilities, and the z-score**

# %% [markdown]
# In this activity, we'll analyze a dataset that closely approximates a normal distribution: the number of dendritic branches for neurons of a given type (pyramidal neurons from layer 3 of the human temporal cortex).
# <br> <br>
# As usual, we first need to import the useful libraries.

# %%
# 📦 Import libraries

# %% [markdown]
# ### **Load data**
#
# Load the dataset by running the cell below. We'll also add code to inspect the size of the dataset and display the first 20 rows.

# %%
# Load dendritic_branches_layer3.csv

# Display the first 20 rows

# %% [markdown]
# ### **Visualize the distribution**
#
# As we've done before, let's visualize this data as a histogram

# %%
# Plot the data listed under the "Dendritic_branches" column

# %% [markdown]
# **Questions❓**
# - Based on the histogram, would you say the distribution looks normally distributed?
# - What are some features of the distribution that tell us this?

# %% [markdown]
# ### **Let's solve some questions...**
#
# Now that we’ve established that data looks reasonably close to a normal distribution, let’s use properties of a normal distribution to answer some questions.
# <br><br>
#
# **Using z-scores to convert a raw score into a percentile score (i.e., a probability)**
# <br>
#
# > ***Question:** What is the probability that this kind of neuron (a pyramidal neuron from layer 3 of the human temporal cortex!) has less than 45 dendritic branches?*

# %% [markdown]
# #### **Step 1: Calculate the standard score (a.k.a., the z-score)**
#
# Remember that the z score indicates how far above or below the mean a value of 45 branches is, in units of standard deviations.
# <br>
#
# To find this, we need to use the formula
# <br>
#
# **z = (raw score - mean) / standard deviation**
# <br>
#
# Notice that this involves finding the mean and standard deviation of our distribution. Let’s do this and find the z-score in the code cell below.

# %%
# First let's find the mean and standard deviation of our distribution 

# Now let's use it to calculate the z-score

# %% [markdown]
# #### **Step 2: Convert the z-score to a probability (using the table provided)**
# **![][image1]**
#
# [image1]: <data:image/png;base64,...>

# %% [markdown]
# We see that the probability corresponding to a z-score of 2.01 is p = 0.9778. This means that there is a 97.78% chance that a neuron has less than 45 dendritic branches!
# <br>
#
# > ***Question:** How can we find the probability that a neuron has more than 45 dendritic branches?*

# %% [markdown]
# **Using z-scores to convert a percentile/probability back into a raw score**
#
# > ***Question:** What number of dendritic branches marks the 80th percentile of the distribution (such that 80% of neurons have less branches and 20% of neurons have more branches?)*
#
# **Step 1: Convert probability to a z-score**
#
# Now, the order of steps is reversed! First we need to consult the table to find the z-score value that corresponds to a probability of 0.80
# <br>
#
# Once we've found this, we can use the formula below to convert the z-score into the original unit of measurement (i.e., the number of branches).
#
# **X = mean + (z)*(standard deviation)**
#
# In the cell below, let's write code to find this calculation

# %%
# Since the closest to 80th percentile is 0.8023 the z-score we're going to be using will be 0.85

# %% [markdown]
# ### **✅ Summary**
#
# In this notebook, you:
# - Examined a distribution to verify that data is normally distributed
# - Practiced converting raw scores to a standard score (and vice versa) in order to ask questions about the probability of neurons having a certain number of dendritic branches.
# <br>
#
# 🎉 Great work!
